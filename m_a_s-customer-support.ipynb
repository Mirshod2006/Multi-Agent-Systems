# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29
# Out:
# Requirement already satisfied: crewai==0.28.8 in c:\users\xamra\anaconda3\lib\site-packages (0.28.8)
# Requirement already satisfied: crewai_tools==0.1.6 in c:\users\xamra\anaconda3\lib\site-packages (0.1.6)
# Requirement already satisfied: langchain_community==0.0.29 in c:\users\xamra\anaconda3\lib\site-packages (0.0.29)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.98 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (0.1.113)
# Requirement already satisfied: instructor<0.6.0,>=0.5.2 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (0.5.2)
# Requirement already satisfied: langchain<0.2.0,>=0.1.10 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (0.1.13)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (1.37.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (1.26.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (1.26.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (1.26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (2.8.2)
# Requirement already satisfied: python-dotenv==1.0.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (1.0.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in c:\users\xamra\anaconda3\lib\site-packages (from crewai==0.28.8) (2023.12.25)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.22 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (0.4.24)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.4 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (0.5.7)
# Requirement already satisfied: pyright<2.0.0,>=1.1.350 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (1.1.373)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (8.3.2)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (2.32.2)
# Requirement already satisfied: selenium<5.0.0,>=4.18.1 in c:\users\xamra\anaconda3\lib\site-packages (from crewai_tools==0.1.6) (4.23.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (3.9.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (0.6.7)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (0.1.52)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (0.1.93)
# Requirement already satisfied: numpy<2,>=1 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (1.26.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\xamra\anaconda3\lib\site-packages (from langchain_community==0.0.29) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\xamra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\xamra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\xamra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\xamra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\xamra\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community==0.0.29) (1.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\xamra\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->crewai_tools==0.1.6) (2.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.110.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\xamra\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.30.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.18.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.26.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.47b0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.64.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\xamra\anaconda3\lib\site-packages (from chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.10.6)
# Requirement already satisfied: colorama in c:\users\xamra\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.7->crewai==0.28.8) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\xamra\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.29) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\xamra\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.29) (0.9.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.13.2)
# Requirement already satisfied: clarifai<11.0.0,>=10.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (10.5.4)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.60.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.1.43)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.1.5)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.1.7)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (4.3.1)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.3.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (13.7.1)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.7.5)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.7.0)
# Requirement already satisfied: PyGithub<2.0.0,>=1.59.1 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (1.59.1)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.38 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (3.1.43)
# Requirement already satisfied: youtube-transcript-api<0.7.0,>=0.6.1 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (0.6.2)
# Requirement already satisfied: yt_dlp<2024.0.0,>=2023.11.14 in c:\users\xamra\anaconda3\lib\site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (2023.12.30)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in c:\users\xamra\anaconda3\lib\site-packages (from instructor<0.6.0,>=0.5.2->crewai==0.28.8) (0.15)
# Requirement already satisfied: deprecation in c:\users\xamra\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in c:\users\xamra\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in c:\users\xamra\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in c:\users\xamra\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (0.9.2)
# Requirement already satisfied: semver>=3.0 in c:\users\xamra\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (3.0.2)
# Requirement already satisfied: cachetools in c:\users\xamra\anaconda3\lib\site-packages (from lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (4.2.2)
# Requirement already satisfied: pyarrow>=12 in c:\users\xamra\anaconda3\lib\site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (14.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\xamra\anaconda3\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai==0.28.8) (1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from langchain<0.2.0,>=0.1.10->crewai==0.28.8) (0.0.2)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\xamra\anaconda3\lib\site-packages (from langchain-core<0.2.0,>=0.1.33->langchain_community==0.0.29) (23.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\xamra\anaconda3\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai==0.28.8) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\xamra\anaconda3\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai==0.28.8) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\xamra\anaconda3\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai==0.28.8) (0.27.0)
# Requirement already satisfied: sniffio in c:\users\xamra\anaconda3\lib\site-packages (from openai<2.0.0,>=1.13.3->crewai==0.28.8) (1.3.0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai==0.28.8) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.0.0,>=6.0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai==0.28.8) (6.11.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai==0.28.8) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.26.0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai==0.28.8) (1.26.0)
# Requirement already satisfied: opentelemetry-proto==1.26.0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai==0.28.8) (1.26.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-proto==1.26.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai==0.28.8) (4.25.4)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai==0.28.8) (0.47b0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\xamra\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.4.2->crewai==0.28.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\xamra\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.4.2->crewai==0.28.8) (2.20.1)
# Requirement already satisfied: nodeenv>=1.6.0 in c:\users\xamra\anaconda3\lib\site-packages (from pyright<2.0.0,>=1.1.350->crewai_tools==0.1.6) (1.9.1)
# Requirement already satisfied: iniconfig in c:\users\xamra\anaconda3\lib\site-packages (from pytest<9.0.0,>=8.0.0->crewai_tools==0.1.6) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\xamra\anaconda3\lib\site-packages (from pytest<9.0.0,>=8.0.0->crewai_tools==0.1.6) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\xamra\anaconda3\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai_tools==0.1.6) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\xamra\anaconda3\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai_tools==0.1.6) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\xamra\anaconda3\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai_tools==0.1.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\xamra\anaconda3\lib\site-packages (from requests<3.0.0,>=2.31.0->crewai_tools==0.1.6) (2024.6.2)
# Requirement already satisfied: trio~=0.17 in c:\users\xamra\anaconda3\lib\site-packages (from selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (0.26.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\xamra\anaconda3\lib\site-packages (from selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\xamra\anaconda3\lib\site-packages (from selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (1.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\xamra\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community==0.0.29) (3.0.1)
# Requirement already satisfied: Mako in c:\users\xamra\anaconda3\lib\site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.3.5)
# Requirement already satisfied: pyproject_hooks in c:\users\xamra\anaconda3\lib\site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.1.0)
# Requirement already satisfied: clarifai-grpc>=10.5.0 in c:\users\xamra\anaconda3\lib\site-packages (from clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (10.6.6)
# Requirement already satisfied: tritonclient>=2.34.0 in c:\users\xamra\anaconda3\lib\site-packages (from clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.48.0)
# Requirement already satisfied: Pillow>=9.5.0 in c:\users\xamra\anaconda3\lib\site-packages (from clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (10.2.0)
# Requirement already satisfied: inquirerpy==0.3.4 in c:\users\xamra\anaconda3\lib\site-packages (from clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.3.4)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\xamra\anaconda3\lib\site-packages (from clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.9.0)
# Requirement already satisfied: contextlib2>=0.5.5 in c:\users\xamra\anaconda3\lib\site-packages (from schema<0.8.0,>=0.7.5->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (21.6.0)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in c:\users\xamra\anaconda3\lib\site-packages (from inquirerpy==0.3.4->clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from inquirerpy==0.3.4->clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (3.0.43)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\xamra\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai==0.28.8) (1.14.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\xamra\anaconda3\lib\site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.37.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from gitpython<4.0.0,>=3.1.38->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (4.0.7)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\xamra\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.19.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.32.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.24.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.18.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.12.4)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.0.5)
# Requirement already satisfied: httpcore==1.* in c:\users\xamra\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai==0.28.8) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\xamra\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai==0.28.8) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\xamra\anaconda3\lib\site-packages (from importlib-metadata<=8.0.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai==0.28.8) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\xamra\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain<0.2.0,>=0.1.10->crewai==0.28.8) (2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\xamra\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\xamra\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (2.8.2)
# Requirement already satisfied: requests-oauthlib in c:\users\xamra\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\xamra\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.2.2)
# Requirement already satisfied: cohere<6.0,>=5.5 in c:\users\xamra\anaconda3\lib\site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (5.6.2)
# Requirement already satisfied: coloredlogs in c:\users\xamra\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\xamra\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (24.3.25)
# Requirement already satisfied: sympy in c:\users\xamra\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.47b0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.47b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.47b0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.47b0)
# Requirement already satisfied: opentelemetry-util-http==0.47b0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.47b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (68.2.2)
# Requirement already satisfied: asgiref~=3.0 in c:\users\xamra\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.47b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\xamra\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\xamra\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (2.2.1)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\xamra\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (2.4.0)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\xamra\anaconda3\lib\site-packages (from PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (1.5.0)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\xamra\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\xamra\anaconda3\lib\site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai_tools==0.1.6) (1.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\xamra\anaconda3\lib\site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\xamra\anaconda3\lib\site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\xamra\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.23.2)
# Requirement already satisfied: sortedcontainers in c:\users\xamra\anaconda3\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (2.4.0)
# Requirement already satisfied: outcome in c:\users\xamra\anaconda3\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (1.3.0.post0)
# Requirement already satisfied: cffi>=1.14 in c:\users\xamra\anaconda3\lib\site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\xamra\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\xamra\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.0.29) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\xamra\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\xamra\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\xamra\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\xamra\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (12.0)
# Requirement already satisfied: mutagen in c:\users\xamra\anaconda3\lib\site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (1.47.0)
# Requirement already satisfied: pycryptodomex in c:\users\xamra\anaconda3\lib\site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (3.20.0)
# Requirement already satisfied: brotli in c:\users\xamra\anaconda3\lib\site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (1.0.9)
# Requirement already satisfied: pycparser in c:\users\xamra\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium<5.0.0,>=4.18.1->crewai_tools==0.1.6) (2.21)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in c:\users\xamra\anaconda3\lib\site-packages (from cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.34.119)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in c:\users\xamra\anaconda3\lib\site-packages (from cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.9.5)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\xamra\anaconda3\lib\site-packages (from cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in c:\users\xamra\anaconda3\lib\site-packages (from cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in c:\users\xamra\anaconda3\lib\site-packages (from cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.32.0.20240712)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\xamra\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.38->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (4.0.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\xamra\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.62.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\xamra\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\xamra\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.7.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\xamra\anaconda3\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.5.0)
# Requirement already satisfied: filelock in c:\users\xamra\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\xamra\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (2023.10.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\xamra\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.1.0)
# Requirement already satisfied: cryptography>=3.3.1 in c:\users\xamra\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai_tools==0.1.6) (42.0.2)
# Requirement already satisfied: python-rapidjson>=0.9.1 in c:\users\xamra\anaconda3\lib\site-packages (from tritonclient>=2.34.0->clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.19)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\xamra\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (10.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\xamra\anaconda3\lib\site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\xamra\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (1.3.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.119 in c:\users\xamra\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.34.119)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\xamra\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\xamra\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.5->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.10.1)
# Requirement already satisfied: pyreadline3 in c:\users\xamra\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai_tools==0.1.6) (3.4.1)
# Requirement already satisfied: wcwidth in c:\users\xamra\anaconda3\lib\site-packages (from prompt-toolkit<4.0.0,>=3.0.1->inquirerpy==0.3.4->clarifai<11.0.0,>=10.0.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\xamra\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai==0.28.8) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\xamra\anaconda3\lib\site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv, find_dotenv

def load_env():
    _ = load_dotenv(find_dotenv())

def get_openai_api_key():
    load_env()
    return os.getenv('OPENAI_API_KEY')

# %%
from crewai import Agent,Task,Crew
openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = 'gpt-3.5-turbo'
print(openai_api_key)
# Out:
# None

# %%
support_agent = Agent(
    role="Senior Support Representative",
	goal="Be the most friendly and helpful "
        "support representative in your team",
	backstory=(
		"You work at crewAI (https://crewai.com) and "
        " are now working on providing "
		"support to {customer}, a super important customer "
        " for your company."
		"You need to make sure that you provide the best support!"
		"Make sure to provide full complete answers, "
        " and make no assumptions."
	),
	allow_delegation=False,
	verbose=True
)

# %%
support_quality_assurance_agent = Agent(
	role="Support Quality Assurance Specialist",
	goal="Get recognition for providing the "
    "best support quality assurance in your team",
	backstory=(
		"You work at crewAI (https://crewai.com) and "
        "are now working with your team "
		"on a request from {customer} ensuring that "
        "the support representative is "
		"providing the best support possible.\n"
		"You need to make sure that the support representative "
        "is providing full"
		"complete answers, and make no assumptions."
	),
	verbose=True
)

# %%
from crewai_tools import SerperDevTool, \
                         ScrapeWebsiteTool, \
                         WebsiteSearchTool

# %%
docs_scrape_tool = ScrapeWebsiteTool(
    website_url="https://docs.crewai.com/how-to/Creating-a-Crew-and-kick-it-off/"
)

# %%
inquiry_resolution = Task(
    description=(
        "{customer} just reached out with a super important ask:\n"
	    "{inquiry}\n\n"
        "{person} from {customer} is the one that reached out. "
		"Make sure to use everything you know "
        "to provide the best support possible."
		"You must strive to provide a complete "
        "and accurate response to the customer's inquiry."
    ),
    expected_output=(
	    "A detailed, informative response to the "
        "customer's inquiry that addresses "
        "all aspects of their question.\n"
        "The response should include references "
        "to everything you used to find the answer, "
        "including external data or solutions. "
        "Ensure the answer is complete, "
		"leaving no questions unanswered, and maintain a helpful and friendly "
		"tone throughout."
    ),
	tools=[docs_scrape_tool],
    agent=support_agent,
)

# %%
quality_assurance_review = Task(
    description=(
        "Review the response drafted by the Senior Support Representative for {customer}'s inquiry. "
        "Ensure that the answer is comprehensive, accurate, and adheres to the "
		"high-quality standards expected for customer support.\n"
        "Verify that all parts of the customer's inquiry "
        "have been addressed "
		"thoroughly, with a helpful and friendly tone.\n"
        "Check for references and sources used to "
        " find the information, "
		"ensuring the response is well-supported and "
        "leaves no questions unanswered."
    ),
    expected_output=(
        "A final, detailed, and informative response "
        "ready to be sent to the customer.\n"
        "This response should fully address the "
        "customer's inquiry, incorporating all "
		"relevant feedback and improvements.\n"
		"Don't be too formal, we are a chill and cool company "
	    "but maintain a professional and friendly tone throughout."
    ),
    agent=support_quality_assurance_agent,
)

# %%
crew = Crew(
  agents=[support_agent, support_quality_assurance_agent],
  tasks=[inquiry_resolution, quality_assurance_review],
  verbose=2,
  memory=True
)

# %% [markdown]
# <h3>I will change below part with some other variables</h3>
# <h4>Input parameters should be changed with</h4>
# <ul>
# <li> <h4 style="color:red">customer</h4></li>
# <li> <h4 style="color:red">person</h4></li>
# <li> <h4 style="color:red">inquiry</h4></li>
# </ul>
# <h4>variables!!!</h4>

# %%
inputs = {
    "customer": "DeepLearningAI",
    "person": "Andrew Ng",
    "inquiry": "I need help with setting up a Crew "
               "and kicking it off, specifically "
               "how can I add memory to my crew? "
               "Can you provide guidance?"
}
result = crew.kickoff(inputs=inputs)

# %%
from IPython.display import Markdown
Markdown(result)
